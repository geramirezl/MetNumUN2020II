# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 2 -1

def df(z):
    return 2 * z

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2 = -1

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5
    m = 1 # Newton's method for roots of multiplicity >1 https://math.stackexchange.com/questions/93156/newtons-method-for-roots-of-multiplicity-1/93158

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - m*f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2-1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
print("zoom out")
display1(zoom=1)
display1(zoom=2)
display1(zoom=3)
display1(zoom=4)
display1(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %% [markdown]
# # Newton iterates form z=10.0 + 0.0j

# %%
z=1.0 + 1.0j
r=[]
i=[]
eps = 1e-3 # max error allowed
for k in range(200):
  dz = df(z)
  znext = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))

  z = znext
  
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# # Newton iterates form z=-(10.0 + 0.0j)

# %%
z=-10.0 -  10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# # Newton iterates form z=0.0 + 10.0j

# %%
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# # Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# # Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-11-dfb212e0f9a1> in <module>()
#       5 for k in range(200):
#       6   dz = df(z)
# ----> 7   z = z - f(z) / dz # Newton iteration
#       8   r.append(np.real(z))
#       9   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# # 1. Plot the following functions in a x range that include that include the vertex and the roots (if there are roots)

# %% [markdown]
# # $x^2$

# %%
def f(z):
    return z ** 2


x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# # $(x-1)^2$

# %%
def f(z):
    return (z-1) ** 2


x = np.linspace(-2.0,4.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=(x-1)^2')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# # $x^2 -1$

# %%
def f(z):
    return (z) ** 2  -1


x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2 -1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# # $x^2 + 1$

# %%
def f(z):
    return (z) ** 2  + 1


x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2 + 1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# # 2.Apply the Classic and Po Shen Loh 's methods for solving the following quadratic equations

# %% [markdown]
# # $x^2=0$

# %%
def f(z):
    return z ** 2

x=0
print(f(x))
# Out:
# 0

# %% [markdown]
# ## Classic method
#
# $$ ax^2+bx+c=0$$
#
# Para resolver la ecuación usamos:
#
# $$  x=\frac{-b\pm\sqrt{b^2 -4ac}}{2a}=0$$

# %%
import math

def classicroot1(a,b,c):
    x1=((-b)+(math.sqrt(b**2 -(4*a*c))))/2*a
    return x1

def classicroot2(a,b,c):
    x2=((-b)-(math.sqrt(b**2 -(4*a*c))))/2*a
    return x2

# %%
a=1
b=0
c=0

if(classicroot1(a,b,c)!=classicroot2(a,b,c)):
  print("Las soluciones a la ecuación son:  ")
  print("x1 =  ",classicroot1(a,b,c))
  print("x2 = ",classicroot2(a,b,c))

else:
  print("La solución a la ecuación es:  ")
  print("x =  ",classicroot1(a,b,c))
# Out:
# La solución a la ecuación es:
# x =   0.0

# %% [markdown]
# ## Po Shen Loh's method
#
# $$ x^2+Bx+C=0$$
#
# Para resolver la ecuación usamos:
#
#  1. Queremos hallar un r y un s con suma **-B** y producto **C**.
#  2. Los dos números que suman **-B** son $-\frac{B}{2}\pm u$
#  3. Y el producto debe ser **C**,es decir, $\frac{B}{4}- u^2=C$
#  4. La raiz cuadrada siempre da un $u$ valido $ u=\pm\sqrt{\frac{B}{4}-C}$
#  5. Los resultados de $-\frac{B}{2}\pm u$ funcionan como r y s, y son las raices tales que $$ x^2+Bx+C=(x-r)(x-s)=0$$

# %%
  import math
  u=0

  def alternativeroot1(B,C):
    u=math.sqrt((B**2/4)-C)
    r= -(B/2)  + u
    return r
  def alternativeroot2(B,C):
    u=math.sqrt((B**2/4)-C)
    s= -(B/2)  - u
    return s

# %%
B=0
C=0
print("La primera raiz resultante es: ",alternativeroot1(B,C))
print("La segunda raiz resultante es: ",alternativeroot2(B,C))
# Out:
# La primera raiz resultante es:  0.0
# La segunda raiz resultante es:  -0.0

# %% [markdown]
# # $(x-1)^2=0$

# %% [markdown]
# Primero convertimos esta ecuación a una ecuación de la forma $$ ax^2+bx+c=0$$
#
# Podemos resolver que $(x-1)^2=(x-1)(x-1)$
# Y esto resulta a: $$x^2-2x+1$$

# %% [markdown]
# ## Classic method
#  $$a=1$$
#  $$b=-2$$
#  $$c=1$$

# %%
a=1
b=-2
c=1

if(classicroot1(a,b,c)!=classicroot2(a,b,c)):
  print("Las soluciones a la ecuación son:  ")
  print("x1 =  ",classicroot1(a,b,c))
  print("x2 = ",classicroot2(a,b,c))

else:
  print("La solución a la ecuación es:  ")
  print("x =  ",classicroot1(a,b,c))
# Out:
# La solución a la ecuación es:
# x =   1.0

# %% [markdown]
# ## Po Shen Loh 's  method
#
#  $$B=-2$$
#  $$C=1$$

# %%
B=-2
C=1
print("La primera raiz resultante es: ",alternativeroot1(B,C))
print("La segunda raiz resultante es: ",alternativeroot2(B,C))
# Out:
# La primera raiz resultante es:  1.0
# La segunda raiz resultante es:  1.0

# %% [markdown]
# # $x^2-1=0$

# %% [markdown]
# ## Classic method
#  $$a=1$$
#  $$b=0$$
#  $$c=-1$$

# %%
a=1
b=0
c=-1

if(classicroot1(a,b,c)!=classicroot2(a,b,c)):
  print("Las soluciones a la ecuación son:  ")
  print("x1 =  ",classicroot1(a,b,c))
  print("x2 = ",classicroot2(a,b,c))

else:
  print("La solución a la ecuación es:  ")
  print("x =  ",classicroot1(a,b,c))
# Out:
# Las soluciones a la ecuación son:
# x1 =   1.0
# x2 =  -1.0

# %% [markdown]
# ## Po Shen Loh 's  method
#
#  $$B=0$$
#  $$C=-1$$

# %%
B=0
C=-1
print("La primera raiz resultante es: ",alternativeroot1(B,C))
print("La segunda raiz resultante es: ",alternativeroot2(B,C))
# Out:
# La primera raiz resultante es:  1.0
# La segunda raiz resultante es:  -1.0

# %% [markdown]
# # $x^2+1=0$

# %% [markdown]
# ## Classic method
#  $$a=1$$
#  $$b=0$$
#  $$c=1$$

# %%
a=1
b=0
c=1

if(classicroot1(a,b,c)!=classicroot2(a,b,c)):
  print("Las soluciones a la ecuación son:  ")
  print("x1 =  ",classicroot1(a,b,c))
  print("x2 = ",classicroot2(a,b,c))

else:
  print("La solución a la ecuación es:  ")
  print("x =  ",classicroot1(a,b,c))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-d9a2c463b364> in <module>()
#       3 c=1
#       4
# ----> 5 if(classicroot1(a,b,c)!=classicroot2(a,b,c)):
#       6   print("Las soluciones a la ecuación son:  ")
#       7   print("x1 =  ",classicroot1(a,b,c))
#
# <ipython-input-24-1f56f2eca7df> in classicroot1(a, b, c)
#       2
#       3 def classicroot1(a,b,c):
# ----> 4     x1=((-b)+(math.sqrt(b**2 -(4*a*c))))/2*a
#       5     return x1
#       6
#
# ValueError: math domain error

# %% [markdown]
# ## Po Shen Loh 's  method
#
#  $$B=0$$
#  $$C=1$$

# %%
B=0
C=1
print("La primera raiz resultante es: ",alternativeroot1(B,C))
print("La segunda raiz resultante es: ",alternativeroot2(B,C))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-b617716cf039> in <module>()
#       1 B=0
#       2 C=1
# ----> 3 print("La primera raiz resultante es: ",alternativeroot1(B,C))
#       4 print("La segunda raiz resultante es: ",alternativeroot2(B,C))
#
# <ipython-input-31-39830628dbc1> in alternativeroot1(B, C)
#       3
#       4 def alternativeroot1(B,C):
# ----> 5   u=math.sqrt((B**2/4)-C)
#       6   r= -(B/2)  + u
#       7   return r
#
# ValueError: math domain error

# %% [markdown]
# Ambos métodos resultan en error ya que la función $x^2+1=0$ no tiene valor definido en los reales.

# %% [markdown]
# # 3.To plot the newton fractals for the corresponding complex quadratic polynomials.
# # 4.Plot the Newton iterates for points on the positive and negative axes for the complex quadratic polynomials
# # 5.Plot he Newton iterates for points on the diagonals in the four quadrants and 0.0 + 0.0j for the complex quadratic polynomials

# %% [markdown]
# # $z^2=0$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 2 

def df(z):
    return 2 * z

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 0
    r2 = 0

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5
    m = 1 # Newton's method for roots of multiplicity >1 https://math.stackexchange.com/questions/93156/newtons-method-for-roots-of-multiplicity-1/93158

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - m*f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display1(zoom=1)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
z=1.0 + 1.0j
r=[]
i=[]
eps = 1e-3 # max error allowed
for k in range(200):
  dz = df(z)
  znext = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))

  z = znext
  
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=-(10.0 + 0.0j)

# %%
z=-10.0 -  10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 10.0j

# %%
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-66-dfb212e0f9a1> in <module>()
#       5 for k in range(200):
#       6   dz = df(z)
# ----> 7   z = z - f(z) / dz # Newton iteration
#       8   r.append(np.real(z))
#       9   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# # $(z-1)^2=0$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return (z -1)** 2 

def df(z):
    return 2 * (z-1)

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2 = -1

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5
    m = 1 # Newton's method for roots of multiplicity >1 https://math.stackexchange.com/questions/93156/newtons-method-for-roots-of-multiplicity-1/93158

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - m*f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=(Z-1)^2')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display1(zoom=1)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
z=1.0 + 1.0j
r=[]
i=[]
eps = 1e-3 # max error allowed
for k in range(200):
  dz = df(z)
  znext = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))

  z = znext
  
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=-(10.0 + 0.0j)

# %%
z=-10.0 -  10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 10.0j

# %%
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-73-dfb212e0f9a1> in <module>()
#       5 for k in range(200):
#       6   dz = df(z)
# ----> 7   z = z - f(z) / dz # Newton iteration
#       8   r.append(np.real(z))
#       9   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# # $z^2 -1=0$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 2 -1

def df(z):
    return 2 * z

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2 = -1

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5
    m = 1 # Newton's method for roots of multiplicity >1 https://math.stackexchange.com/questions/93156/newtons-method-for-roots-of-multiplicity-1/93158

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - m*f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display1(zoom=1)
display1(zoom=2)
display1(zoom=3)
display1(zoom=4)
display1(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
z=1.0 + 1.0j
r=[]
i=[]
eps = 1e-3 # max error allowed
for k in range(200):
  dz = df(z)
  znext = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))

  z = znext
  
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=-(10.0 + 0.0j)

# %%
z=-10.0 -  10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 10.0j

# %%
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-82-dfb212e0f9a1> in <module>()
#       5 for k in range(200):
#       6   dz = df(z)
# ----> 7   z = z - f(z) / dz # Newton iteration
#       8   r.append(np.real(z))
#       9   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# # $z^2 +1=0$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 2 + 1

def df(z):
    return 2 * z

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2 = -1

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5
    m = 1 # Newton's method for roots of multiplicity >1 https://math.stackexchange.com/questions/93156/newtons-method-for-roots-of-multiplicity-1/93158

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - m*f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2+1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
print("zoom out")
display1(zoom=1)
display1(zoom=2)
display1(zoom=3)
display1(zoom=4)
display1(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
z=1.0 + 1.0j
r=[]
i=[]
eps = 1e-3 # max error allowed
for k in range(200):
  dz = df(z)
  znext = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))

  z = znext
  
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=-(10.0 + 0.0j)

# %%
z=-10.0 -  10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 10.0j

# %%
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-89-dfb212e0f9a1> in <module>()
#       5 for k in range(200):
#       6   dz = df(z)
# ----> 7   z = z - f(z) / dz # Newton iteration
#       8   r.append(np.real(z))
#       9   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# # 6.Describe in one after cell after each quadratic function the regions where starting points $x_0$ converge and to which root does it converge. Also which regions do not converge and why.

# %% [markdown]
# # $x^2=0$

# %% [markdown]
# Todo valor real que se tome en esta función como $x_0$ convergerá a la raiz x=0 , ya que es la única raiz que tiene la función.

# %% [markdown]
# # $(x-1)^2=0$

# %% [markdown]
# Todo valor real que se tome en esta función como $x_0$ convergerá a la raiz x=1 , ya que es la única raiz que tiene la función.

# %% [markdown]
# # $x^2 -1 =0$

# %% [markdown]
# Todo valor positivo que se tome como $x_0$ convergerá a 1 y todo valor negativo que se tome como $x_0$ convergerá a -1
# Esto porque las dos raices que tiene la función son 1 y -1 , y se puede observar que al tomar una derivada en la parte positiva de esta función , tiene una pendiente positiva y, en la parte negativa tiene una pendiente negativa, lo cual define a que punto va a converger
#
# También podemos decir que en el punto $x_0=0$ no converge la función a una raiz, ya que su derivada es 0 y no se puede seguir una iteración para buscar una raiz.

# %% [markdown]
# # $x^2 +1=0$

# %% [markdown]
# No converge a ninguna raiz con ningún $x_0$ real ya que no tiene una raiz definida en los reales.
